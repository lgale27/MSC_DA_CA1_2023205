# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
from scipy.stats import iqr, skew
from matplotlib.ticker import PercentFormatter
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error
from sklearn.tree import DecisionTreeRegressor

# %% [markdown]
# ## EDA

# %%
df = pd.read_csv("E2001.csv")

# %%
df.head()
# Out:
#                           Statistic Label County         Sex  CensusYear  \
# 0  Population at Each Census 1841 to 2016  State  Both sexes        1841
# 1  Population at Each Census 1841 to 2016  State  Both sexes        1851
# 2  Population at Each Census 1841 to 2016  State  Both sexes        1861
# 3  Population at Each Census 1841 to 2016  State  Both sexes        1871
# 4  Population at Each Census 1841 to 2016  State  Both sexes        1881
#
#      UNIT    VALUE
# 0  Number  6528799
# 1  Number  5111557
# 2  Number  4402111
# 3  Number  4053187
# 4  Number  3870020

# %%
df.shape
# Out:
# (2025, 6)

# %%
df.dtypes
# Out:
# Statistic Label    object
# County             object
# Sex                object
# CensusYear          int64
# UNIT               object
# VALUE               int64
# dtype: object

# %%
df.describe()
# Out:
#         CensusYear         VALUE
# count  2025.000000  2.025000e+03
# mean   1943.560000  1.822066e+05
# std      52.710705  5.052940e+05
# min    1841.000000  1.201300e+04
# 25%    1901.000000  3.630800e+04
# 50%    1956.000000  6.288100e+04
# 75%    1986.000000  1.115240e+05
# max    2016.000000  6.528799e+06

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2025 entries, 0 to 2024
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Statistic Label  2025 non-null   object
#  1   County           2025 non-null   object
#  2   Sex              2025 non-null   object
#  3   CensusYear       2025 non-null   int64
#  4   UNIT             2025 non-null   object
#  5   VALUE            2025 non-null   int64
# dtypes: int64(2), object(4)
# memory usage: 95.0+ KB

# %%
df.isna().sum()
# Out:
# Statistic Label    0
# County             0
# Sex                0
# CensusYear         0
# UNIT               0
# VALUE              0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.rename(columns = {"Statistic Label": "Stat_label", "CensusYear": "Year", "VALUE": "Population"}, inplace = True)
df.drop(columns = ["UNIT"], inplace = True)
df
# Out:
#                                   Stat_label    County         Sex  Year  \
# 0     Population at Each Census 1841 to 2016     State  Both sexes  1841
# 1     Population at Each Census 1841 to 2016     State  Both sexes  1851
# 2     Population at Each Census 1841 to 2016     State  Both sexes  1861
# 3     Population at Each Census 1841 to 2016     State  Both sexes  1871
# 4     Population at Each Census 1841 to 2016     State  Both sexes  1881
# ...                                      ...       ...         ...   ...
# 2020  Population at Each Census 1841 to 2016  Monaghan      Female  1996
# 2021  Population at Each Census 1841 to 2016  Monaghan      Female  2002
# 2022  Population at Each Census 1841 to 2016  Monaghan      Female  2006
# 2023  Population at Each Census 1841 to 2016  Monaghan      Female  2011
# 2024  Population at Each Census 1841 to 2016  Monaghan      Female  2016
#
#       Population
# 0        6528799
# 1        5111557
# 2        4402111
# 3        4053187
# 4        3870020
# ...          ...
# 2020       25155
# 2021       25787
# 2022       27414
# 2023       30042
# 2024       30520
#
# [2025 rows x 5 columns]

# %%
print(f'Stat_label: {df["Stat_label"].unique()}')
print(f'Stat_label: {df["Stat_label"].nunique()}')
# Out:
# Stat_label: ['Population at Each Census 1841 to 2016']
# Stat_label: 1

# %%
print(f'County: {df["County"].unique()}')
print(f'County: {df["County"].nunique()}')
# Out:
# County: ['State' 'Carlow' 'Dublin' 'Kildare' 'Kilkenny' 'Laois' 'Longford' 'Louth'
#  'Meath' 'Offaly' 'Westmeath' 'Wexford' 'Wicklow' 'Clare' 'Cork' 'Kerry'
#  'Limerick' 'Tipperary' 'Waterford' 'Galway' 'Leitrim' 'Mayo' 'Roscommon'
#  'Sligo' 'Cavan' 'Donegal' 'Monaghan']
# County: 27

# %%
print(f'Sex: {df["Sex"].unique()}')
print(f'Sex: {df["Sex"].nunique()}')
# Out:
# Sex: ['Both sexes' 'Male' 'Female']
# Sex: 3

# %%
print(f'Year: {df["Year"].unique()}')
print(f'Year: {df["Year"].nunique()}')
# Out:
# Year: [1841 1851 1861 1871 1881 1891 1901 1911 1926 1936 1946 1951 1956 1961
#  1966 1971 1979 1981 1986 1991 1996 2002 2006 2011 2016]
# Year: 25

# %% [markdown]
# - Testing if the data is consistent by splitting it in the section that has generalized data and the section that has the complete set of data

# %%
df.loc[df["Sex"] == "Both sexes"].loc[df["County"] == "State"].groupby("Year")["Population"].sum()
# Out:
# Year
# 1841    6528799
# 1851    5111557
# 1861    4402111
# 1871    4053187
# 1881    3870020
# 1891    3468694
# 1901    3221823
# 1911    3139688
# 1926    2971992
# 1936    2968420
# 1946    2955107
# 1951    2960593
# 1956    2898264
# 1961    2818341
# 1966    2884002
# 1971    2978248
# 1979    3368217
# 1981    3443405
# 1986    3540643
# 1991    3525719
# 1996    3626087
# 2002    3917203
# 2006    4239848
# 2011    4588252
# 2016    4761865
# Name: Population, dtype: int64

# %%
df.loc[df["Sex"] != "Both sexes"].loc[df["County"] != "State"].groupby("Year")["Population"].sum()
# Out:
# Year
# 1841    6528799
# 1851    5111557
# 1861    4402111
# 1871    4053187
# 1881    3870020
# 1891    3468694
# 1901    3221823
# 1911    3139688
# 1926    2971992
# 1936    2968420
# 1946    2955107
# 1951    2960593
# 1956    2898264
# 1961    2818341
# 1966    2884002
# 1971    2978248
# 1979    3368217
# 1981    3443405
# 1986    3540643
# 1991    3525719
# 1996    3626087
# 2002    3917203
# 2006    4239848
# 2011    4588252
# 2016    4761865
# Name: Population, dtype: int64

# %%
df.loc[df["County"] == "State"].loc[df["Sex"] != "Both sexes"].groupby("Year")["Population"].sum()
# Out:
# Year
# 1841    6528799
# 1851    5111557
# 1861    4402111
# 1871    4053187
# 1881    3870020
# 1891    3468694
# 1901    3221823
# 1911    3139688
# 1926    2971992
# 1936    2968420
# 1946    2955107
# 1951    2960593
# 1956    2898264
# 1961    2818341
# 1966    2884002
# 1971    2978248
# 1979    3368217
# 1981    3443405
# 1986    3540643
# 1991    3525719
# 1996    3626087
# 2002    3917203
# 2006    4239848
# 2011    4588252
# 2016    4761865
# Name: Population, dtype: int64

# %%
df.loc[df["County"] != "State"].loc[df["Sex"] != "Both sexes"].groupby("Year")["Population"].sum()
# Out:
# Year
# 1841    6528799
# 1851    5111557
# 1861    4402111
# 1871    4053187
# 1881    3870020
# 1891    3468694
# 1901    3221823
# 1911    3139688
# 1926    2971992
# 1936    2968420
# 1946    2955107
# 1951    2960593
# 1956    2898264
# 1961    2818341
# 1966    2884002
# 1971    2978248
# 1979    3368217
# 1981    3443405
# 1986    3540643
# 1991    3525719
# 1996    3626087
# 2002    3917203
# 2006    4239848
# 2011    4588252
# 2016    4761865
# Name: Population, dtype: int64

# %% [markdown]
# - Sectioning the data in the Generalized one (Including the general data of "Both sexes" and "State" which includes all the counties)

# %%
df_general = df.loc[df["Sex"] == "Both sexes"].loc[df["County"] == "State"]
df_general
# Out:
#                                 Stat_label County         Sex  Year  \
# 0   Population at Each Census 1841 to 2016  State  Both sexes  1841
# 1   Population at Each Census 1841 to 2016  State  Both sexes  1851
# 2   Population at Each Census 1841 to 2016  State  Both sexes  1861
# 3   Population at Each Census 1841 to 2016  State  Both sexes  1871
# 4   Population at Each Census 1841 to 2016  State  Both sexes  1881
# 5   Population at Each Census 1841 to 2016  State  Both sexes  1891
# 6   Population at Each Census 1841 to 2016  State  Both sexes  1901
# 7   Population at Each Census 1841 to 2016  State  Both sexes  1911
# 8   Population at Each Census 1841 to 2016  State  Both sexes  1926
# 9   Population at Each Census 1841 to 2016  State  Both sexes  1936
# 10  Population at Each Census 1841 to 2016  State  Both sexes  1946
# 11  Population at Each Census 1841 to 2016  State  Both sexes  1951
# 12  Population at Each Census 1841 to 2016  State  Both sexes  1956
# 13  Population at Each Census 1841 to 2016  State  Both sexes  1961
# 14  Population at Each Census 1841 to 2016  State  Both sexes  1966
# 15  Population at Each Census 1841 to 2016  State  Both sexes  1971
# 16  Population at Each Census 1841 to 2016  State  Both sexes  1979
# 17  Population at Each Census 1841 to 2016  State  Both sexes  1981
# 18  Population at Each Census 1841 to 2016  State  Both sexes  1986
# 19  Population at Each Census 1841 to 2016  State  Both sexes  1991
# 20  Population at Each Census 1841 to 2016  State  Both sexes  1996
# 21  Population at Each Census 1841 to 2016  State  Both sexes  2002
# 22  Population at Each Census 1841 to 2016  State  Both sexes  2006
# 23  Population at Each Census 1841 to 2016  State  Both sexes  2011
# 24  Population at Each Census 1841 to 2016  State  Both sexes  2016
#
#     Population
# 0      6528799
# 1      5111557
# 2      4402111
# 3      4053187
# 4      3870020
# 5      3468694
# 6      3221823
# 7      3139688
# 8      2971992
# 9      2968420
# 10     2955107
# 11     2960593
# 12     2898264
# 13     2818341
# 14     2884002
# 15     2978248
# 16     3368217
# 17     3443405
# 18     3540643
# 19     3525719
# 20     3626087
# 21     3917203
# 22     4239848
# 23     4588252
# 24     4761865

# %% [markdown]
# - Sectioning the data in the Expanded one (Including "Both sexes" which is Male and Female and "State" all the counties)

# %%
df_expanded = df.loc[df["Sex"] != "Both sexes"].loc[df["County"] != "State"]
df_expanded
# Out:
#                                   Stat_label    County     Sex  Year  \
# 100   Population at Each Census 1841 to 2016    Carlow    Male  1841
# 101   Population at Each Census 1841 to 2016    Carlow    Male  1851
# 102   Population at Each Census 1841 to 2016    Carlow    Male  1861
# 103   Population at Each Census 1841 to 2016    Carlow    Male  1871
# 104   Population at Each Census 1841 to 2016    Carlow    Male  1881
# ...                                      ...       ...     ...   ...
# 2020  Population at Each Census 1841 to 2016  Monaghan  Female  1996
# 2021  Population at Each Census 1841 to 2016  Monaghan  Female  2002
# 2022  Population at Each Census 1841 to 2016  Monaghan  Female  2006
# 2023  Population at Each Census 1841 to 2016  Monaghan  Female  2011
# 2024  Population at Each Census 1841 to 2016  Monaghan  Female  2016
#
#       Population
# 100        42428
# 101        33016
# 102        28139
# 103        25464
# 104        23078
# ...          ...
# 2020       25155
# 2021       25787
# 2022       27414
# 2023       30042
# 2024       30520
#
# [1300 rows x 5 columns]

# %%
df_density_resume = df_expanded.loc[df_expanded["Year"] == 2016].groupby("County")["Population"].sum()
df_density_resume
# Out:
# County
# Carlow         56932
# Cavan          76176
# Clare         118817
# Cork          542868
# Donegal       159192
# Dublin       1347359
# Galway        258058
# Kerry         147707
# Kildare       222504
# Kilkenny       99232
# Laois          84697
# Leitrim        32044
# Limerick      194899
# Longford       40873
# Louth         128884
# Mayo          130507
# Meath         195044
# Monaghan       61386
# Offaly         77961
# Roscommon      64544
# Sligo          65535
# Tipperary     159553
# Waterford     116176
# Westmeath      88770
# Wexford       149722
# Wicklow       142425
# Name: Population, dtype: int64

# %% [markdown]
# - Plotting the Population number by Year to see how it has behaved

# %%
plt.figure(figsize = (16,12))
ax = sns.lineplot(x = "Year", y = "Population", data = df_general);
plt.title("Population by Year")
plt.show()

# %% [markdown]
# - Plotting the Population Number by County for an specific year

# %%
plt.figure(figsize = (10,8))
ax = sns.barplot(x = "Year", y = "Population", hue = "County", data = df_expanded.loc[df["County"] != "State"].loc[df["Year"] == 1841], palette="pastel");
plt.title("Population Number by County")
plt.show()

# %% [markdown]
# - Plotting the Population number in percentage for an specific year

# %%
plt.figure(figsize = (10,8))
ax = sns.histplot(x = "County", weights = "Population",multiple="dodge", stat="percent", data = df_expanded.loc[df["County"] != "State"].loc[df["Year"] == 1841]);
plt.xticks(
    rotation=90, 
    horizontalalignment='right',
    fontweight='light',
    fontsize='x-large'  
)
plt.title("Population Number by County")
plt.show()

# %%
df.loc[df["Sex"] != "Both sexes"].loc[df["County"] != "State"].loc[df["Year"] == 1841].groupby(["Year","Sex"])["Population"].sum()
# Out:
# Year  Sex
# 1841  Female    3306314
#       Male      3222485
# Name: Population, dtype: int64

# %% [markdown]
# - Distribution of Population by County along the years

# %%
years= df_expanded["Year"].unique()


# Create a subplot for each year
fig, axes = plt.subplots(nrows=len(years), figsize=(10, 200), sharey=True)

# Loop for over the years
for i, year in enumerate(years):
    data = df_expanded.loc[df_expanded["Year"]==year]
#     sns.barplot(data=data, x="CensusYear",y="VALUE", hue = "County", ax=axes[i])
    sns.histplot(x = "County", weights = "Population",multiple="dodge",hue="Sex", stat="percent", data = data, ax=axes[i]);
    axes[i].set_title(f'Distribution by County in {year}')
    axes[i].tick_params(labelrotation=90)

plt.show()

# %% [markdown]
# - Density tests

# %%
df_density = df.loc[df["Sex"] == "Both sexes"].loc[df["County"] != "State"]
df_density
# Out:
#                                   Stat_label    County         Sex  Year  \
# 75    Population at Each Census 1841 to 2016    Carlow  Both sexes  1841
# 76    Population at Each Census 1841 to 2016    Carlow  Both sexes  1851
# 77    Population at Each Census 1841 to 2016    Carlow  Both sexes  1861
# 78    Population at Each Census 1841 to 2016    Carlow  Both sexes  1871
# 79    Population at Each Census 1841 to 2016    Carlow  Both sexes  1881
# ...                                      ...       ...         ...   ...
# 1970  Population at Each Census 1841 to 2016  Monaghan  Both sexes  1996
# 1971  Population at Each Census 1841 to 2016  Monaghan  Both sexes  2002
# 1972  Population at Each Census 1841 to 2016  Monaghan  Both sexes  2006
# 1973  Population at Each Census 1841 to 2016  Monaghan  Both sexes  2011
# 1974  Population at Each Census 1841 to 2016  Monaghan  Both sexes  2016
#
#       Population
# 75         86228
# 76         68078
# 77         57137
# 78         51650
# 79         46568
# ...          ...
# 1970       51313
# 1971       52593
# 1972       55997
# 1973       60483
# 1974       61386
#
# [650 rows x 5 columns]

# %%
dict= {"Cork": 7457, "Galway": 6148, "Mayo": 5585, "Donegal": 4841, "Kerry": 4746, "Tipperary": 4303, "Tyrone": 3155, "Clare": 3147, "Antrim": 2844, "Limerick": 2686, "Roscommon": 2547, "Down": 2448, "Wexford": 2352, "Meath": 2342, "Derry": 2074, "Kilkenny": 2061, "Wicklow": 2024, "Offaly": 2000, "Cavan": 1931, "Westmeath": 1838, "Waterford": 1837, "Sligo": 1836, "Laois": 1719, "Kildare": 1693, "Fermanagh": 1691, "Leitrim": 1691, "Monaghan": 1294 , "Armagh": 1254, "Longford": 1091, "Dublin": 921, "Carlow": 896, "Louth": 820}

# %%
County_Area = []

for i,row in df_density.iterrows():
    if row["County"] in dict:
        County_Area.append(dict[row["County"]])

df_density["County_Area"] = County_Area
df_density.head()
# Out:
#                                 Stat_label  County         Sex  Year  \
# 75  Population at Each Census 1841 to 2016  Carlow  Both sexes  1841
# 76  Population at Each Census 1841 to 2016  Carlow  Both sexes  1851
# 77  Population at Each Census 1841 to 2016  Carlow  Both sexes  1861
# 78  Population at Each Census 1841 to 2016  Carlow  Both sexes  1871
# 79  Population at Each Census 1841 to 2016  Carlow  Both sexes  1881
#
#     Population  County_Area
# 75       86228          896
# 76       68078          896
# 77       57137          896
# 78       51650          896
# 79       46568          896

# %%
df_density.loc[df_density["County"] == "Dublin"].loc[df_density["Year"] == 2016]
# Out:
#                                  Stat_label  County         Sex  Year  \
# 174  Population at Each Census 1841 to 2016  Dublin  Both sexes  2016
#
#      Population  County_Area
# 174     1347359          921

# %%
df_density.loc[(df_density["County"] == "Dublin") & (df_density["Year"] == 2016)]["Population"]/df_density.loc[(df_density["County"] == "Dublin") & (df_density["Year"] == 2016)]["County_Area"]
# Out:
# 174    1462.93051
# dtype: float64

# %%
df_density["Population_Density"] = df_density["Population"]/df_density["County_Area"]

# %%
df_density.head()
# Out:
#                                 Stat_label  County         Sex  Year  \
# 75  Population at Each Census 1841 to 2016  Carlow  Both sexes  1841
# 76  Population at Each Census 1841 to 2016  Carlow  Both sexes  1851
# 77  Population at Each Census 1841 to 2016  Carlow  Both sexes  1861
# 78  Population at Each Census 1841 to 2016  Carlow  Both sexes  1871
# 79  Population at Each Census 1841 to 2016  Carlow  Both sexes  1881
#
#     Population  County_Area  Population_Density
# 75       86228          896           96.236607
# 76       68078          896           75.979911
# 77       57137          896           63.768973
# 78       51650          896           57.645089
# 79       46568          896           51.973214

# %%
df_density_resume = df_density.groupby("County")["Population_Density"].sum()
df_density_resume
# Out:
# County
# Carlow        1235.233259
# Cavan         1139.302434
# Clare          904.137909
# Cork          1487.949980
# Donegal        825.597810
# Dublin       20491.231270
# Galway         848.465192
# Kerry          807.126212
# Kildare       1497.455995
# Kilkenny      1057.683649
# Laois          941.589878
# Leitrim        794.160260
# Limerick      1601.309382
# Longford      1014.402383
# Louth         2617.251220
# Mayo           750.925157
# Meath         1083.075149
# Monaghan      1418.743431
# Offaly         839.884000
# Roscommon      867.828033
# Sligo         1047.308824
# Tipperary      986.708111
# Waterford     1358.719652
# Westmeath      952.692057
# Wexford       1216.426871
# Wicklow       1044.704545
# Name: Population_Density, dtype: float64

# %%
#plt.figure(figsize = (10,8))
#ax = sns.barplot(x = "VALUE", y = "Population_Density", hue = "County", data = df_density);
#plt.title("Population Density by county")
#plt.show()
sns.barplot(data = df_density.loc[df_density["Year"] == 2016], x = "County", y = "Population_Density")
plt.xticks(
    rotation = 90, 
    horizontalalignment='right',
    fontweight='light',
    fontsize='x-large'  
)
plt.title("Density Population")
plt.show()

# %% [markdown]
# - Denisty in Dublin along the years

# %%
sns.barplot(data = df_density.loc[df_density["County"] == "Dublin"], x = "Year", y = "Population_Density", hue = "County")
plt.xticks(
    rotation = 90, 
    horizontalalignment='right',
    fontweight='light',
    fontsize='x-large'  
)
plt.title("Density Population")
plt.show()

# %% [markdown]
# - Growth rate

# %%
#df_general.loc[(df_general["Population"])]

# %%
a = int(df_general.loc[df_general["Year"] == 2016]["Population"])
a
# Out:
# 4761865

# %%
b = int(df_general.loc[df_general["Year"] == 2011]["Population"])
b
# Out:
# 4588252

# %%
grate = ((a-b)/b)*100
print(grate)
# Out:
# 3.783859299794344

# %%
grate
# Out:
# 3.783859299794344

# %%
x = int(df_general.loc[df_general["Year"] == 1841]["Population"])
x
# Out:
# 6528799

# %%
growth_rate = []
years = df_general["Year"].unique()

for i,row in df_general.iterrows():
    if row["Year"] == 1841:
        growth_rate.append(0)
    else:
        population = int(row["Population"])
        index = np.where(years == row["Year"])[0][0]
        prev_year = years[index-1]
        populationprev = int(df_general.loc[df_general["Year"] == prev_year]["Population"])
        grate = ((population - populationprev) / populationprev)*100
        growth_rate.append(grate)
        
df_general["growth_rate"] = growth_rate

# %%
df_general
# Out:
#                                 Stat_label County         Sex  Year  \
# 0   Population at Each Census 1841 to 2016  State  Both sexes  1841
# 1   Population at Each Census 1841 to 2016  State  Both sexes  1851
# 2   Population at Each Census 1841 to 2016  State  Both sexes  1861
# 3   Population at Each Census 1841 to 2016  State  Both sexes  1871
# 4   Population at Each Census 1841 to 2016  State  Both sexes  1881
# 5   Population at Each Census 1841 to 2016  State  Both sexes  1891
# 6   Population at Each Census 1841 to 2016  State  Both sexes  1901
# 7   Population at Each Census 1841 to 2016  State  Both sexes  1911
# 8   Population at Each Census 1841 to 2016  State  Both sexes  1926
# 9   Population at Each Census 1841 to 2016  State  Both sexes  1936
# 10  Population at Each Census 1841 to 2016  State  Both sexes  1946
# 11  Population at Each Census 1841 to 2016  State  Both sexes  1951
# 12  Population at Each Census 1841 to 2016  State  Both sexes  1956
# 13  Population at Each Census 1841 to 2016  State  Both sexes  1961
# 14  Population at Each Census 1841 to 2016  State  Both sexes  1966
# 15  Population at Each Census 1841 to 2016  State  Both sexes  1971
# 16  Population at Each Census 1841 to 2016  State  Both sexes  1979
# 17  Population at Each Census 1841 to 2016  State  Both sexes  1981
# 18  Population at Each Census 1841 to 2016  State  Both sexes  1986
# 19  Population at Each Census 1841 to 2016  State  Both sexes  1991
# 20  Population at Each Census 1841 to 2016  State  Both sexes  1996
# 21  Population at Each Census 1841 to 2016  State  Both sexes  2002
# 22  Population at Each Census 1841 to 2016  State  Both sexes  2006
# 23  Population at Each Census 1841 to 2016  State  Both sexes  2011
# 24  Population at Each Census 1841 to 2016  State  Both sexes  2016
#
#     Population  growth_rate
# 0      6528799     0.000000
# 1      5111557   -21.707545
# 2      4402111   -13.879254
# 3      4053187    -7.926288
# 4      3870020    -4.519086
# 5      3468694   -10.370127
# 6      3221823    -7.117117
# 7      3139688    -2.549333
# 8      2971992    -5.341168
# 9      2968420    -0.120189
# 10     2955107    -0.448488
# 11     2960593     0.185645
# 12     2898264    -2.105288
# 13     2818341    -2.757616
# 14     2884002     2.329775
# 15     2978248     3.267890
# 16     3368217    13.093906
# 17     3443405     2.232279
# 18     3540643     2.823891
# 19     3525719    -0.421505
# 20     3626087     2.846738
# 21     3917203     8.028379
# 22     4239848     8.236617
# 23     4588252     8.217370
# 24     4761865     3.783859

# %%
sns.lineplot(data = df_general, x = "Year", y = "growth_rate")
plt.xticks(
    rotation = 90, 
    horizontalalignment='right',
    fontweight='light',
    fontsize='x-large'  
)
plt.title("Density Population")
plt.show()

# %% [markdown]
# ## Statistics

# %% [markdown]
# - Descriptive statistics

# %%
sns.histplot(df_general["Population"], kde = True)
# Out:
# <AxesSubplot:xlabel='Population', ylabel='Count'>

# %% [markdown]
# right skewed  = Proved by formula

# %%
s = skew(df_general["Population"], axis = 0, bias= True)
s
# Out:
# 1.533544396636998

# %%
np.median(df_general["Population"])
# Out:
# 3468694.0

# %%
sns.boxplot(df_general["Population"])
# Out:
# C:\Users\ledag\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Population'>

# %%
np.std(df_general["Population"], ddof =1)
# Out:
# 877986.3024496738

# %%
np.quantile(df_general["Population"],[0,0.25,0.5,0.75,1])
# Out:
# array([2818341., 2971992., 3468694., 4053187., 6528799.])

# %%
q1 = np.quantile(df_general["Population"],0.25)
q1
# Out:
# 2971992.0

# %%
q3 = np.quantile(df_general["Population"],0.75)
q3
# Out:
# 4053187.0

# %%
from scipy.stats import iqr

# %%
iqr = iqr(df_general["Population"])
iqr
# Out:
# 1081195.0

# %% [markdown]
# Outliers

# %%
dfprueba = df_general[((df_general["Population"]<(q1-1.5*iqr)) | (df_general["Population"]<(q3+1.5*iqr))) ]

# %%
dfprueba.shape
# Out:
# (24, 6)

# %%
df_general.shape
# Out:
# (25, 6)

# %%
outliers = (df_general[~((df_general["Population"]<(q1-(1.5*iqr))) | (df_general["Population"]<(q3+(1.5*iqr)))) ] )
outliers
# Out:
#                                Stat_label County         Sex  Year  \
# 0  Population at Each Census 1841 to 2016  State  Both sexes  1841
#
#    Population  growth_rate
# 0     6528799          0.0

# %% [markdown]
# ## Machine learning

# %% [markdown]
# - Linear Regression with two variables

# %%
#Splitting the data
X = df_general[["Year","growth_rate"]]
y = df_general["Population"]

# %%
# Split the data set into Training and Testing parts
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.30, random_state = 100)

# Display the Number of rows and columns before (X, y) and after Splitting (X_train, X_test, y_train, y_test)
X.shape, y.shape, X_train.shape, X_test.shape, y_train.shape, y_test.shape

#Fit model
my_lm = LinearRegression()
my_lm.fit(X = X_train, y = y_train)


train_fcst = my_lm.predict(X_train)
test_fcst = my_lm.predict(X_test)
predicted_population = my_lm.predict(X)


#Store the R2 error into train_r2 and test_r2
train_r2 = r2_score(y_train, train_fcst)
test_r2 = r2_score(y_test, test_fcst)

#Display the training and test score
print(train_r2, test_r2)

#Plot result
sns.scatterplot(x = "Year", y = "Population", data = df_general , color='blue', label='Actual Population')
sns.lineplot(x = "Year", y = predicted_population, data = df_general, color='red', label='Linear Regression Line')

# Show the plot
plt.show()
# Out:
# 0.29433909551902715 -1.0223271905407532

# %%
#Adding lagged variable
df_general["population_l1"] = df_general["Population"].shift(1)
df_general["population_l2"] = df_general["Population"].shift(2)
df_general["population_l3"] = df_general["Population"].shift(3)
df_general["population_l4"] = df_general["Population"].shift(4)
df_general["population_l5"] = df_general["Population"].shift(5)

# Display the first 10 records
df_general.head(10)
# Out:
#                                Stat_label County         Sex  Year  \
# 0  Population at Each Census 1841 to 2016  State  Both sexes  1841
# 1  Population at Each Census 1841 to 2016  State  Both sexes  1851
# 2  Population at Each Census 1841 to 2016  State  Both sexes  1861
# 3  Population at Each Census 1841 to 2016  State  Both sexes  1871
# 4  Population at Each Census 1841 to 2016  State  Both sexes  1881
# 5  Population at Each Census 1841 to 2016  State  Both sexes  1891
# 6  Population at Each Census 1841 to 2016  State  Both sexes  1901
# 7  Population at Each Census 1841 to 2016  State  Both sexes  1911
# 8  Population at Each Census 1841 to 2016  State  Both sexes  1926
# 9  Population at Each Census 1841 to 2016  State  Both sexes  1936
#
#    Population  growth_rate  population_l1  population_l2  population_l3  \
# 0     6528799     0.000000            NaN            NaN            NaN
# 1     5111557   -21.707545      6528799.0            NaN            NaN
# 2     4402111   -13.879254      5111557.0      6528799.0            NaN
# 3     4053187    -7.926288      4402111.0      5111557.0      6528799.0
# 4     3870020    -4.519086      4053187.0      4402111.0      5111557.0
# 5     3468694   -10.370127      3870020.0      4053187.0      4402111.0
# 6     3221823    -7.117117      3468694.0      3870020.0      4053187.0
# 7     3139688    -2.549333      3221823.0      3468694.0      3870020.0
# 8     2971992    -5.341168      3139688.0      3221823.0      3468694.0
# 9     2968420    -0.120189      2971992.0      3139688.0      3221823.0
#
#    population_l4  population_l5
# 0            NaN            NaN
# 1            NaN            NaN
# 2            NaN            NaN
# 3            NaN            NaN
# 4      6528799.0            NaN
# 5      5111557.0      6528799.0
# 6      4402111.0      5111557.0
# 7      4053187.0      4402111.0
# 8      3870020.0      4053187.0
# 9      3468694.0      3870020.0

# %%
# Drop Null values from the dataframe
df_general = df_general.dropna()

# Display the first 10 records
df_general.head(10)
# Out:
#                                 Stat_label County         Sex  Year  \
# 5   Population at Each Census 1841 to 2016  State  Both sexes  1891
# 6   Population at Each Census 1841 to 2016  State  Both sexes  1901
# 7   Population at Each Census 1841 to 2016  State  Both sexes  1911
# 8   Population at Each Census 1841 to 2016  State  Both sexes  1926
# 9   Population at Each Census 1841 to 2016  State  Both sexes  1936
# 10  Population at Each Census 1841 to 2016  State  Both sexes  1946
# 11  Population at Each Census 1841 to 2016  State  Both sexes  1951
# 12  Population at Each Census 1841 to 2016  State  Both sexes  1956
# 13  Population at Each Census 1841 to 2016  State  Both sexes  1961
# 14  Population at Each Census 1841 to 2016  State  Both sexes  1966
#
#     Population  growth_rate  population_l1  population_l2  population_l3  \
# 5      3468694   -10.370127      3870020.0      4053187.0      4402111.0
# 6      3221823    -7.117117      3468694.0      3870020.0      4053187.0
# 7      3139688    -2.549333      3221823.0      3468694.0      3870020.0
# 8      2971992    -5.341168      3139688.0      3221823.0      3468694.0
# 9      2968420    -0.120189      2971992.0      3139688.0      3221823.0
# 10     2955107    -0.448488      2968420.0      2971992.0      3139688.0
# 11     2960593     0.185645      2955107.0      2968420.0      2971992.0
# 12     2898264    -2.105288      2960593.0      2955107.0      2968420.0
# 13     2818341    -2.757616      2898264.0      2960593.0      2955107.0
# 14     2884002     2.329775      2818341.0      2898264.0      2960593.0
#
#     population_l4  population_l5
# 5       5111557.0      6528799.0
# 6       4402111.0      5111557.0
# 7       4053187.0      4402111.0
# 8       3870020.0      4053187.0
# 9       3468694.0      3870020.0
# 10      3221823.0      3468694.0
# 11      3139688.0      3221823.0
# 12      2971992.0      3139688.0
# 13      2968420.0      2971992.0
# 14      2955107.0      2968420.0

# %%
#Fitting the full Linear Regression model

# Create X and y objects
X = df_general[["Year", "growth_rate", "population_l1", "population_l2", "population_l3", "population_l4", "population_l5"]]
y = df_general["Population"]

# Train Test Split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.20, random_state = 12345, shuffle = False)

# Fit the model
my_lm = LinearRegression()
my_lm.fit(X = X_train, y = y_train)

# Calculate the train Forecasting
train_fcst = my_lm.predict(X_train)
test_fcst = my_lm.predict(X_test)
predicted_population = my_lm.predict(X)

# Calculate teh r2 score for train and test
train_r2 = r2_score(y_train, train_fcst)
test_r2 = r2_score(y_test, test_fcst)

# Display the results for train and test
print(train_r2, test_r2)

#Plot result
sns.scatterplot(x = "Year", y = "Population", data = df_general , color='blue', label='Actual Population')
sns.lineplot(x = "Year", y = predicted_population, data = df_general, color='red', label='Linear Regression Line')

# Show the plot
plt.show()
# Out:
# 0.9996020319247473 0.9290040962705103

# %% [markdown]
# - Ridge Regression

# %%
from sklearn.linear_model import Ridge

# Train the Ridge() mode by calling a fit() method
ridge = Ridge().fit(X_train, y_train)

# Display the score by using ridge object
print("Training set score: {:.2f}".format(ridge.score(X_train, y_train)))
print("Test set score: {:.2f}".format(ridge.score(X_test, y_test)))
# Out:
# Training set score: 1.00
# Test set score: 0.93

# %%
# alpha = 10 is a parameter using a fit() method
ridge10 = Ridge(alpha = 10).fit(X_train, y_train)

# Display the score values for Ridge function
print("Training set score: {:.2f}".format(ridge10.score(X_train, y_train)))
print("Test set score: {:.2f}".format(ridge10.score(X_test, y_test)))
# Out:
# Training set score: 1.00
# Test set score: 0.91

# %% [markdown]
# - Lasso Regression

# %%
from sklearn.linear_model import Lasso
lasso = Lasso().fit(X_train, y_train)
print("Training set score: {:.2f}".format(lasso.score(X_train, y_train)))
print("Test set score: {:.2f}".format(lasso.score(X_test, y_test)))
print("Number of features used: {}".format(np.sum(lasso.coef_ != 0)))
# Out:
# Training set score: 1.00
# Test set score: 0.93
# Number of features used: 7
# C:\Users\ledag\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 163027021.35064054, tolerance: 116457900.58834375
#   model = cd_fast.enet_coordinate_descent(

# %%
#increasing the default setting of "max_iter",
lasso001 = Lasso(alpha=0.01).fit(X_train, y_train)
print("Training set score: {:.2f}".format(lasso001.score(X_train, y_train)))
print("Test set score: {:.2f}".format(lasso001.score(X_test, y_test)))
print("Number of features used: {}".format(np.sum(lasso001.coef_ != 0)))
# Out:
# Training set score: 1.00
# Test set score: 0.93
# Number of features used: 7
# C:\Users\ledag\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 230842137.72559363, tolerance: 116457900.58834375
#   model = cd_fast.enet_coordinate_descent(

# %% [markdown]
# - Decision Tree regression

# %%
# Method or Function for Linear Regression plot
def lin_regplot(X, y, model):
    plt.scatter(X, y, c = 'blue')
    plt.plot(X, model.predict(X), color = 'red', linewidth = 2)    
    return

# %%
# import DecisionTreeRegressor from the sklearn library
#from sklearn.tree import DecisionTreeRegressor

# Store the feature or attribute values in X and y
X = df_general[["Year", "growth_rate"]].values
y = df_general["Population"].values

# Initialise an object by calling a method DecisionTreeRegressor()
tree = DecisionTreeRegressor(max_depth = 3)
tree.fit(X, y)


sns.scatterplot(x = "Year", y = "Population", data = df_general , color='blue', label='Actual Population')
sns.lineplot(x = "Year", y = tree.predict(X), data = df_general, color='red', label='Linear Regression Line')

plt.show()
